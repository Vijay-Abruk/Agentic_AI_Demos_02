# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absolufy-imports                         0.3.1
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.12.15
# aiosignal                                1.4.0
# aiosqlite                                0.21.0
# altair                                   5.5.0
# annotated-types                          0.7.0
# anyio                                    4.10.0
# appdirs                                  1.4.4
# asttokens                                3.0.0
# attrs                                    25.3.0
# Authlib                                  1.6.1
# backoff                                  2.2.1
# banks                                    2.2.0
# bcrypt                                   4.3.0
# beautifulsoup4                           4.13.4
# blinker                                  1.9.0
# build                                    1.3.0
# ...
